# %% [markdown]
# # Using the Presentation Color Style Script
#
# ## Quickstart

# %%
# Import the Script
import presentation as p

# Create data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('../data/creditcard/creditcard.csv').drop_duplicates()
f, ax1 = plt.subplots(1,1,figsize =( 18, 8))
corr = np.abs(data.corr())
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Create the plot
sns.heatmap(
    corr,
    vmax=.8,
    square=True,
    ax=ax1,
    cmap=p.Colors.purples_c,    # <-- use one of the provided color palettes
    mask=mask
)
plt.show()

# %% [markdown]
# ## Showcasing the Premade Palettes

# %%
p.Colors.blues
# Out:
# [(np.float64(0.13333333333333333),
#   np.float64(0.6862745098039216),
#   np.float64(1.0)),
#  (np.float64(0.1340331282646485),
#   np.float64(0.5788282610430713),
#   np.float64(0.8328798342092043)),
#  (np.float64(0.13473292319596367),
#   np.float64(0.471382012282221),
#   np.float64(0.6657596684184085)),
#  (np.float64(0.13543271812727886),
#   np.float64(0.36393576352137075),
#   np.float64(0.4986395026276128)),
#  (np.float64(0.13613251305859403),
#   np.float64(0.25648951476052045),
#   np.float64(0.33151933683681706)),
#  (np.float64(0.1368323079899092),
#   np.float64(0.1490432659996702),
#   np.float64(0.1643991710460213))]

# %%
p.Colors.blues_c

# %%
p.Colors.blues_cr

# %%
p.Colors.purples
# Out:
# [(np.float64(0.15335135842674683),
#   np.float64(0.14258900999146698),
#   np.float64(0.17756411344792813)),
#  (np.float64(0.22699481223159354),
#   np.float64(0.1689731687774873),
#   np.float64(0.3098944280132445)),
#  (np.float64(0.3006382660364403),
#   np.float64(0.19535732756350765),
#   np.float64(0.4422247425785608)),
#  (np.float64(0.374281719841287),
#   np.float64(0.22174148634952798),
#   np.float64(0.5745550571438771)),
#  (np.float64(0.4479251736461337),
#   np.float64(0.24812564513554833),
#   np.float64(0.7068853717091935)),
#  (np.float64(0.5215686274509804),
#   np.float64(0.27450980392156865),
#   np.float64(0.8392156862745098))]

# %%
p.Colors.purples_c

# %%
p.Colors.purples_cr

# %%
p.Colors.greys
# Out:
# [(np.float64(0.14711517657644949),
#   np.float64(0.1478154049738404),
#   np.float64(0.1485061325606309)),
#  (np.float64(0.3012215530258655),
#   np.float64(0.3025660494692684),
#   np.float64(0.303902945264191)),
#  (np.float64(0.45532792947528145),
#   np.float64(0.45731669396469643),
#   np.float64(0.4592997579677511)),
#  (np.float64(0.6094343059246974),
#   np.float64(0.6120673384601244),
#   np.float64(0.6146965706713112)),
#  (np.float64(0.7635406823741134),
#   np.float64(0.7668179829555524),
#   np.float64(0.7700933833748713)),
#  (np.float64(0.9176470588235294),
#   np.float64(0.9215686274509803),
#   np.float64(0.9254901960784314))]

# %%
p.Colors.greys_c

# %%
p.Colors.selected_greys
# Out:
# [(0.058823529411764705, 0.058823529411764705, 0.058823529411764705),
#  (0.29411764705882354, 0.29411764705882354, 0.29411764705882354),
#  (0.32941176470588235, 0.32941176470588235, 0.32941176470588235),
#  (0.45098039215686275, 0.45098039215686275, 0.45098039215686275),
#  (0.6627450980392157, 0.6627450980392157, 0.6627450980392157),
#  (0.9176470588235294, 0.9215686274509803, 0.9254901960784314),
#  (0.9215686274509803, 0.9215686274509803, 0.9215686274509803),
#  (0.9294117647058824, 0.9411764705882353, 0.9490196078431372)]

# %% [markdown]
# ## Further Customization
#
# If you need further fine-tuning, you can create custom color palettes on the fly,
# based on the preselected colors:

# %%
sns.light_palette(p.hex_code('blue'))
# Out:
# [(np.float64(0.9383082187193579),
#   np.float64(0.9441526683007223),
#   np.float64(0.9520023491849271)),
#  (np.float64(0.777313241642153),
#   np.float64(0.8925770366013621),
#   np.float64(0.9616018793479417)),
#  (np.float64(0.6163182645649481),
#   np.float64(0.841001404902002),
#   np.float64(0.9712014095109562)),
#  (np.float64(0.45532328748774314),
#   np.float64(0.7894257732026418),
#   np.float64(0.9808009396739709)),
#  (np.float64(0.2943283104105382),
#   np.float64(0.7378501415032817),
#   np.float64(0.9904004698369854)),
#  (np.float64(0.13333333333333333),
#   np.float64(0.6862745098039216),
#   np.float64(1.0))]

# %%
sns.light_palette(p.hex_code('blue'), as_cmap=True)

# %%
sns.dark_palette(p.hex_code('blue'))
# Out:
# [(np.float64(0.1368323079899092),
#   np.float64(0.1490432659996702),
#   np.float64(0.1643991710460213)),
#  (np.float64(0.13613251305859403),
#   np.float64(0.25648951476052045),
#   np.float64(0.33151933683681706)),
#  (np.float64(0.13543271812727886),
#   np.float64(0.36393576352137075),
#   np.float64(0.4986395026276128)),
#  (np.float64(0.13473292319596367),
#   np.float64(0.471382012282221),
#   np.float64(0.6657596684184085)),
#  (np.float64(0.1340331282646485),
#   np.float64(0.5788282610430713),
#   np.float64(0.8328798342092043)),
#  (np.float64(0.13333333333333333),
#   np.float64(0.6862745098039216),
#   np.float64(1.0))]

# %%
sns.dark_palette(p.hex_code('blue'), as_cmap=True)

# %%
sns.light_palette(p.hex_code('purple'))
# Out:
# [(np.float64(0.9446123302932115),
#   np.float64(0.9424963488512226),
#   np.float64(0.949917852622152)),
#  (np.float64(0.8600035897247652),
#   np.float64(0.8088990398652918),
#   np.float64(0.9277774193526236)),
#  (np.float64(0.7753948491563191),
#   np.float64(0.675301730879361),
#   np.float64(0.9056369860830952)),
#  (np.float64(0.6907861085878728),
#   np.float64(0.5417044218934302),
#   np.float64(0.8834965528135666)),
#  (np.float64(0.6061773680194267),
#   np.float64(0.40810711290749946),
#   np.float64(0.8613561195440382)),
#  (np.float64(0.5215686274509804),
#   np.float64(0.27450980392156865),
#   np.float64(0.8392156862745098))]

# %%
sns.light_palette(p.hex_code('purple'), as_cmap=True)

# %%
sns.dark_palette(p.hex_code('purple'))
# Out:
# [(np.float64(0.15335135842674683),
#   np.float64(0.14258900999146698),
#   np.float64(0.17756411344792813)),
#  (np.float64(0.22699481223159354),
#   np.float64(0.1689731687774873),
#   np.float64(0.3098944280132445)),
#  (np.float64(0.3006382660364403),
#   np.float64(0.19535732756350765),
#   np.float64(0.4422247425785608)),
#  (np.float64(0.374281719841287),
#   np.float64(0.22174148634952798),
#   np.float64(0.5745550571438771)),
#  (np.float64(0.4479251736461337),
#   np.float64(0.24812564513554833),
#   np.float64(0.7068853717091935)),
#  (np.float64(0.5215686274509804),
#   np.float64(0.27450980392156865),
#   np.float64(0.8392156862745098))]

# %%
sns.dark_palette(p.hex_code('purple'), as_cmap=True)
